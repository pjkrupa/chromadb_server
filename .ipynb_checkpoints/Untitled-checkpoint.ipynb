# %%
from tool import Tools

# %%
query_text="according to the GDPR, do i also have to use consent as the legal basis for processing personal data in cases of scientific research?"

# %%
tools = Tools()
result = tools.query_collection(query_text=query_text, collection="gdpr")
# Out:
# RESPONSE TIME: 0.180s
# STATUS: 200
# RESPONSE TIME: 19.380s
# RERANK STATUS: 200
# ...
